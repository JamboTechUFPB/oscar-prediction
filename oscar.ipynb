# %% [markdown]
# # Oscars Best Actress

# %%
OSCARS_url = "https://en.wikipedia.org/wiki/Academy_Award_for_Best_Actress"

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

soup = BeautifulSoup(requests.get(OSCARS_url).text, 'html.parser')
tables = soup.find_all('table', class_='wikitable sortable')

# %%
def isWinner(row):
    return bool(row.find('td',{'style': 'background:#FAEB86;'}))

# %%
df = pd.DataFrame(columns=['ano','nome','personagem','filme','ganhou'])


for table in tables:
    rows = table.find_all('tr')
    current_year = None  # Variável para armazenar o ano atual
    current_filme = None
    
    for row in rows[1:]:
        ano_th = row.find('th', {'style': 'text-align:center;'}) 
        if not ano_th:
             ano_th = row.find('th')
        
        # Se encontrou um th com o estilo, atualiza o ano atual
        if ano_th is not None and ano_th.find('a'):
            current_year = ano_th.find('a').text 
        
        # Usa o ano atual para esta linha
        ano_atual = current_year
        #print(f"Ano para esta linha: {ano_atual}")
        
        # Processa os tds
        tds = row.find_all('td')
        nome = tds[0].find('a').text if tds[0].find('a') else None
        if nome is None:
            nome = tds[0].text.strip()
        personagem = tds[1].find('a').text if tds[1].find('a') else None
        if personagem is None:
             personagem = tds[1].text.strip()
        if len(tds) > 2:
                filme = tds[2].find('a').text if tds[2].find('a') else None
                # Atualiza o filme atual para uso em linhas futuras
                if filme:
                    current_filme = filme
                else:
                    # Usa o filme armazenado anteriormente
                    filme = current_filme
    
        ganhou = isWinner(row)
    
        df = pd.concat(
            [
                df,
                pd.DataFrame(
                    {
                        'ano': [ano_atual],
                        'nome': [nome],
                        'personagem': [personagem],
                        'filme': [filme],
                        'ganhou': [ganhou]
                    }
                )
            ]
    )

# %%
df
# Out:
#      ano                nome                               personagem  \
# 0   1927        Janet Gaynor                                    Diane
# 0   1927              Angela                             Street Angel
# 0   1927            The Wife            Sunrise: A Song of Two Humans
# 0   1927      Louise Dresser                             Mrs. Pleznik
# 0   1927      Gloria Swanson                           Sadie Thompson
# ..   ...                 ...                                      ...
# 0   2024       Cynthia Erivo                           Elphaba Thropp
# 0   2024  Karla Sofía Gascón  Emilia Pérez / Juan "Manitas" Del Monte
# 0   2024       Mikey Madison                     Anora "Ani" Mikheeva
# 0   2024          Demi Moore                        Elisabeth Sparkle
# 0   2024     Fernanda Torres                             Eunice Paiva
#
#               filme ganhou
# 0        7th Heaven   True
# 0        7th Heaven   True
# 0        7th Heaven   True
# 0   A Ship Comes In  False
# 0    Sadie Thompson  False
# ..              ...    ...
# 0            Wicked  False
# 0      Emilia Pérez  False
# 0             Anora  False
# 0     The Substance  False
# 0    I'm Still Here  False
#
# [484 rows x 5 columns]

# %%
#o de 2020 foi adiado para 2021 por causa da pandemia, mas n deixou de ser a edição 93 referente a 2020
df['ano'] = df['ano'].replace('2020/21', '2020')

# %%
vencedoras = df[df['ganhou'] == True]
vencedoras
# Out:
#      ano               nome                     personagem  \
# 0   1927       Janet Gaynor                          Diane
# 0   1927             Angela                   Street Angel
# 0   1927           The Wife  Sunrise: A Song of Two Humans
# 0   1928      Mary Pickford                   Norma Besant
# 0   1929      Norma Shearer           Jerry Bernard Martin
# ..   ...                ...                            ...
# 0   2019    Renée Zellweger                   Judy Garland
# 0   2020  Frances McDormand                           Fern
# 0   2021   Jessica Chastain              Tammy Faye Bakker
# 0   2022      Michelle Yeoh               Evelyn Quan Wang
# 0   2023         Emma Stone                   Bella Baxter
#
#                                 filme ganhou
# 0                          7th Heaven   True
# 0                          7th Heaven   True
# 0                          7th Heaven   True
# 0                            Coquette   True
# 0                        The Divorcee   True
# ..                                ...    ...
# 0                                Judy   True
# 0                           Nomadland   True
# 0              The Eyes of Tammy Faye   True
# 0   Everything Everywhere All at Once   True
# 0                         Poor Things   True
#
# [99 rows x 5 columns]

# %%
print(df[df['nome'] == 'Emma Stone'])
# Out:
#     ano        nome    personagem        filme ganhou
# 0  2016  Emma Stone     Mia Dolan   La La Land   True
# 0  2023  Emma Stone  Bella Baxter  Poor Things   True

# %%
df.to_csv('data/original/oscar.csv', index=False)
print('done')
# Out:
# done
